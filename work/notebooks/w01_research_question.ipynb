# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jawadhussain-git/flyrank-ml-internship-jawad/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
my_lane = """
I chose the Page Performance Prediction lane because it helps identify which pages have the highest potential for improvement. This can help prioritize SEO efforts and improve search visibility using data-driven decisions.
"""

print(my_lane)
# Out:
# I chose the Page Performance Prediction lane because it helps identify which pages have the highest potential for improvement. This can help prioritize SEO efforts and improve search visibility using data-driven decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
research_question = """
Decision:
Which pages should be prioritized for SEO improvement?

Action:
Improve the selected pages by updating content, titles, keywords, and internal links.

Cost of a wrong recommendation:
If the wrong pages are selected, time and resources may be wasted while high-potential pages are ignored.

Why ML helps:
Machine learning can identify patterns in historical search data and help prioritize pages more effectively than manual analysis.
"""

print(research_question)
# Out:
# Decision:
# Which pages should be prioritized for SEO improvement?
#
# Action:
# Improve the selected pages by updating content, titles, keywords, and internal links.
#
# Cost of a wrong recommendation:
# If the wrong pages are selected, time and resources may be wasted while high-potential pages are ignored.
#
# Why ML helps:
# Machine learning can identify patterns in historical search data and help prioritize pages more effectively than manual analysis.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
starter = ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
print("This notebook does not prove that one factor causes higher search performance. It only explores relationships in the available data. Future models should be validated using unseen data before being used for decision-making.")
# Out:
# This notebook does not prove that one factor causes higher search performance. It only explores relationships in the available data. Future models should be validated using unseen data before being used for decision-making.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
